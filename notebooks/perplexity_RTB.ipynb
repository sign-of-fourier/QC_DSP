# %%
import json
import time
import uuid
import base64
import hashlib
from typing import Dict, List, Optional, Tuple
from dataclasses import dataclass, asdict
from datetime import datetime
from enum import Enum
import asyncio

# %% [markdown]
# # OpenRTB Enums

# %%
class AuctionType(Enum):
    FIRST_PRICE = 1
    SECOND_PRICE = 2

class CreativeStatus(Enum):
    APPROVED = 1
    PENDING_REVIEW = 2
    REJECTED = 3

# Data Classes for OpenRTB
@dataclass
class Banner:
    w: int
    h: int
    format: List[Dict] = None
    
    def __post_init__(self):
        if self.format is None:
            self.format = [{"w": self.w, "h": self.h}]

@dataclass
class Imp:
    id: str
    banner: Banner
    tagid: str
    bidfloor: float = 0.0
    bidfloorcur: str = "USD"
    secure: int = 1
    ext: Dict = None

@dataclass
class Site:
    id: str
    domain: str
    page: str
    name: str = "Publisher"
    cat: List[str] = None
    content: Dict = None

@dataclass
class Device:
    ua: str
    ip: str
    devicetype: int = 1  # 1=mobile, 2=personal computer
    make: str = "Apple"
    model: str = "iPhone"
    os: str = "iOS"

@dataclass
class User:
    id: str
    buyeruid: str = None
    keywords: str = ""

@dataclass
class BidRequest:
    id: str
    imp: List[Imp]
    site: Site
    device: Device
    user: User
    at: int = AuctionType.SECOND_PRICE.value
    tmax: int = 100
    cur: List[str] = None
    test: int = 1
    
    def __post_init__(self):
        if self.cur is None:
            self.cur = ["USD"]

@dataclass
class Bid:
    id: str
    impid: str
    price: float
    adid: str
    adm: str
    ext: Dict = None

@dataclass
class SeatBid:
    seat: str
    bid: List[Bid]

@dataclass
class BidResponse:
    id: str
    seatbid: List[SeatBid]
    bidid: str = None
    
    def __post_init__(self):
        if self.bidid is None:
            self.bidid = str(uuid.uuid4())[:8]

# %% [markdown]
# # RTBBidder

# %%
class RTBBidder:
    """Real-Time Bidder implementing OpenRTB protocol"""
    
    def __init__(self, bidder_id: str = "bidder-123", buyer_id: str = "buyer-123"):
        self.bidder_id = bidder_id
        self.buyer_id = buyer_id
        self.stats = {
            "bids_submitted": 0,
            "bids_won": 0,
            "total_spend": 0.0,
            "impressions": []
        }
        self.creatives = {
            "banner-1": {
                "id": "banner-1",
                "width": 300,
                "height": 250,
                "markup": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
                "status": CreativeStatus.APPROVED
            }
        }
    
    def generate_bid_request(self, 
                            publisher_url: str,
                            ad_unit: str,
                            width: int = 300,
                            height: int = 250,
                            bid_floor: float = 0.5) -> BidRequest:
        """Generate OpenRTB BidRequest matching Google's protocol"""
        
        request_id = self._generate_request_id()
        
        banner = Banner(w=width, h=height)
        imp = Imp(
            id="1",
            banner=banner,
            tagid=ad_unit,
            bidfloor=bid_floor,
            ext={"billing_id": [12345]}
        )
        
        site = Site(
            id="site-pub-123",
            domain=publisher_url.split("//")[1].split("/")[0],
            page=publisher_url,
            name="Publisher"
        )
        
        device = Device(
            ua="Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
            ip="192.168.1.100",
            devicetype=1
        )
        
        user = User(
            id=f"user-{uuid.uuid4().hex[:8]}",
            buyeruid=str(uuid.uuid4())
        )
        
        bid_request = BidRequest(
            id=request_id,
            imp=[imp],
            site=site,
            device=device,
            user=user,
            at=AuctionType.SECOND_PRICE.value,
            tmax=100
        )
        
        return bid_request
    
    def evaluate_request(self, bid_request: BidRequest) -> Tuple[float, str]:
        """Apply bidding logic to determine price and creative"""
        
        impression = bid_request.imp[0]
        base_bid = 5.0  # Base CPM in dollars
        
        # Contextual scoring: adjust based on site quality, viewability, etc.
        site_quality_score = self._score_site(bid_request.site)
        viewability_adjustment = 1.0 + (site_quality_score * 0.3)
        
        # Apply viewability metric if available
        if hasattr(impression, 'metric') and impression.metric:
            viewability = impression.metric[0].get('value', 0.5)
            if viewability > 0.5:
                viewability_adjustment *= 1.15
        
        final_bid = base_bid * viewability_adjustment
        final_bid = max(final_bid, impression.bidfloor)
        
        # Select creative
        creative_id = "banner-1"
        
        return round(final_bid, 2), creative_id
    
    def submit_bid(self, 
                   bid_request: BidRequest,
                   bid_price: float,
                   creative_id: str) -> BidResponse:
        """Construct and submit OpenRTB BidResponse"""
        
        impression = bid_request.imp[0]
        creative = self.creatives.get(creative_id)
        
        if not creative:
            raise ValueError(f"Creative {creative_id} not found")
        
        bid = Bid(
            id=str(uuid.uuid4())[:8],
            impid=impression.id,
            price=bid_price,
            adid=creative_id,
            adm=creative["markup"],
            ext={
                "billing_id": 12345,
                "impression_tracking_url": [
                    f"https://track.example.com/imp?auction_id=${{AUCTION_ID}}&price=${{AUCTION_PRICE}}&creative={creative_id}"
                ]
            }
        )
        
        seatbid = SeatBid(seat=self.buyer_id, bid=[bid])
        bid_response = BidResponse(id=bid_request.id, seatbid=[seatbid])
        
        self.stats["bids_submitted"] += 1
        
        return bid_response
    
    def process_bid_feedback(self, 
                            bid_response: BidResponse,
                            feedback: Dict) -> None:
        """Process real-time feedback from Google"""
        
        creative_status = feedback.get("creative_status", 0)
        price = feedback.get("price", 0)
        won = feedback.get("won", False)
        
        if won:
            self.stats["bids_won"] += 1
            self.stats["total_spend"] += price
            self.stats["impressions"].append({
                "timestamp": datetime.now().isoformat(),
                "price": price,
                "creative_status": creative_status,
                "request_id": bid_response.id
            })
    
    def get_performance_metrics(self) -> Dict:
        """Calculate key performance indicators"""
        
        bids = self.stats["bids_submitted"]
        wins = self.stats["bids_won"]
        spend = self.stats["total_spend"]
        
        return {
            "bids_submitted": bids,
            "bids_won": wins,
            "win_rate": (wins / bids * 100) if bids > 0 else 0,
            "total_spend": round(spend, 2),
            "average_cpm": round(spend / wins, 2) if wins > 0 else 0,
            "impressions_count": len(self.stats["impressions"])
        }
    
    # Helper methods
    @staticmethod
    def _generate_request_id() -> str:
        """Generate websafe base64 request ID (no padding)"""
        raw_id = base64.b64encode(uuid.uuid4().bytes)
        websafe = raw_id.decode('ascii').replace('+', '-').replace('/', '_').rstrip('=')
        return websafe
    
    @staticmethod
    def _score_site(site: Site) -> float:
        """Simple site quality scoring (0-1)"""
        score = 0.6
        if "premium" in site.name.lower():
            score += 0.2
        if "https" in site.page:
            score += 0.1
        return min(score, 1.0)
    
    def to_json(self, obj) -> str:
        """Convert OpenRTB objects to JSON"""
        def converter(o):
            if hasattr(o, '__dataclass_fields__'):
                return asdict(o)
            elif isinstance(o, Enum):
                return o.value
            raise TypeError(f"Object of type {o.__class__.__name__} is not JSON serializable")
        
        return json.dumps(obj, default=converter, indent=2)

# %% [markdown]
# # Initialize bidder

# %%
bidder = RTBBidder(bidder_id="my-bidder", buyer_id="my-buyer")

print("=" * 60)
print("Google Authorized Buyers RTB Bidder - OpenRTB Protocol Demo")
print("=" * 60)
# Out:
# ============================================================
# Google Authorized Buyers RTB Bidder - OpenRTB Protocol Demo
# ============================================================

# %%
# Simulate multiple bid requests
for i in range(50):
    print(f"\n--- Auction {i + 1} ---\n")
    
    # Generate bid request
    bid_request = bidder.generate_bid_request(
        publisher_url="https://example-publisher.com/article",
        ad_unit="sidebar-ad-123",
        width=300,
        height=250,
        bid_floor=1.50
    )
    
    print("BID REQUEST (OpenRTB):")
    print(bidder.to_json(bid_request))
    
    # Evaluate and determine bid
    bid_price, creative_id = bidder.evaluate_request(bid_request)
    print(f"\n→ Decision: Bid ${bid_price} CPM with creative {creative_id}")
    
    # Submit bid response
    bid_response = bidder.submit_bid(bid_request, bid_price, creative_id)
    print("\nBID RESPONSE (OpenRTB):")
    print(bidder.to_json(bid_response))
    
    # Simulate feedback from exchange
    won = True if i % 2 == 0 else False
    feedback = {
        "creative_status": CreativeStatus.APPROVED.value,
        "price": bid_price if won else bid_price + 0.50,
        "won": won
    }
    bidder.process_bid_feedback(bid_response, feedback)
    
    result = "✓ WON" if won else "✗ Lost"
    print(f"\n{result}: Feedback - {json.dumps(feedback)}")
    
    time.sleep(0.5)
# Out:
# --- Auction 1 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "hP0yc3oZRRyoMszli49fnQ",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-7e21e9a8",
#     "buyeruid": "0af7ae4b-601a-4f96-ada5-3a335eb596b9",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "hP0yc3oZRRyoMszli49fnQ",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "5e33ee2c",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "2664233a"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 2 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "-HCjXv49RyizaMkF9JiB5Q",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-52e6f55d",
#     "buyeruid": "e6bc2268-fa49-425f-b46b-bb9479d1d974",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "-HCjXv49RyizaMkF9JiB5Q",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "02a8a477",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "d5635c28"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 3 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "-QLurwITRky5P6yvyAfTMA",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-eeb0796f",
#     "buyeruid": "43681a81-0ac2-42a4-a69a-44f86b4d70c6",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "-QLurwITRky5P6yvyAfTMA",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "82513f97",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "2a85fd34"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 4 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "cemJ5Tm9Rkar0XISzvLXWw",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-cedd41a6",
#     "buyeruid": "f840792c-ea73-4818-bcbd-623e3aa81661",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "cemJ5Tm9Rkar0XISzvLXWw",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "b4a42fcb",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "c9bf5a03"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 5 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "Y2_LCHsfRfSp2chFVuXo9Q",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-04766ec4",
#     "buyeruid": "599a4c5e-bd4e-49c7-904d-613ceaf30b62",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "Y2_LCHsfRfSp2chFVuXo9Q",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "2af4f7d7",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "1193a681"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 6 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "l0jJMJqgRx6DIPzE7FEm-w",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-e97c6f27",
#     "buyeruid": "563b57de-d55e-4f8c-9fa6-8c155b3cf0f9",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "l0jJMJqgRx6DIPzE7FEm-w",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "80f5278b",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "f5b2bcee"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 7 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "_47vMmTDTZ26Ngz0Ve56xQ",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-ad2f0a02",
#     "buyeruid": "dc863bf2-08b3-4010-93a2-035b61430529",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "_47vMmTDTZ26Ngz0Ve56xQ",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "edd2066a",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "43e58699"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 8 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "wQ-Zj20jT1WWdd2W6n9RwQ",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-7f0ea697",
#     "buyeruid": "82d87826-82a9-457b-8af2-7eaa98567497",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "wQ-Zj20jT1WWdd2W6n9RwQ",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "1e7ea703",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "9cacefc9"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 9 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "B4chCuWSS5O1O5TZUH-nIg",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-9e587df4",
#     "buyeruid": "52880720-3659-4a32-8384-51c7125e087d",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "B4chCuWSS5O1O5TZUH-nIg",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "d78ba9b4",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "04459b41"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 10 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "OH17fQpgQoy7k2caJUgYmQ",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-d41778f6",
#     "buyeruid": "b5899688-8e1c-40c9-9f71-e47b3e43a984",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "OH17fQpgQoy7k2caJUgYmQ",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "525f3836",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "6bcf2b8a"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 11 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "xoYMAZ9yROmbnr9mfp6lcA",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-57e75648",
#     "buyeruid": "c280ec8f-3036-4353-bfad-d14927a5ea2a",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "xoYMAZ9yROmbnr9mfp6lcA",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "68b6f223",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "97b61049"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 12 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "C0Xfw9GTRJmc5_t9ezImBg",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-e5410ef7",
#     "buyeruid": "b8d2009d-8172-47e7-bc89-aafa8fbe349e",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "C0Xfw9GTRJmc5_t9ezImBg",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "59b998b1",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "a4777c53"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 13 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "Tw66AjDNSr2tcwXiTPUFRw",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-8677898b",
#     "buyeruid": "6b4d9813-02ef-4eb2-80c3-d2060e0cf2a5",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "Tw66AjDNSr2tcwXiTPUFRw",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "f6b0db48",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "3173a72e"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 14 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "efJKgOMbR1mE_H3XrIoAgA",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-d0f3d726",
#     "buyeruid": "29db0f85-b1a0-45dd-9c73-7ce6bfaf9167",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "efJKgOMbR1mE_H3XrIoAgA",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "812232f6",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "187e8f31"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 15 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "gKZ01Z5ASmKejFNMWDEGwA",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-76f3d9cd",
#     "buyeruid": "42a81a9a-15ea-4bfd-9f67-cbd7d0f1fcd2",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "gKZ01Z5ASmKejFNMWDEGwA",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "2eefb9f1",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "4193cfe2"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 16 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "cZb1l1HtRwe1eRezYmh7xw",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-33547376",
#     "buyeruid": "afa7bf62-eea7-411d-82dc-da2aa338e14c",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "cZb1l1HtRwe1eRezYmh7xw",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "a111119f",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "a81fcedd"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 17 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "0gUkcLtTSHiA6OsfceePxg",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-ec92b699",
#     "buyeruid": "33bed6ae-7e23-4298-a2c3-6333cba5deed",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "0gUkcLtTSHiA6OsfceePxg",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "6a039a6e",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "52348f08"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 18 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "hww130h_TmqOeSTrrznx-g",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-d0cb3122",
#     "buyeruid": "fbc7d9ef-7f9e-4b44-8d63-d2dc36a73e2f",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "hww130h_TmqOeSTrrznx-g",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "e8d1a849",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "c243983c"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 19 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "wy3g7sH0TReR-9lKH_akCg",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-a4eda2e5",
#     "buyeruid": "14cdc0f8-f7cb-4e0f-88f3-78f1ab825362",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "wy3g7sH0TReR-9lKH_akCg",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "183b51dc",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "b2941591"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 20 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "iAsx2ZwLT6K2iGkA6PCt1g",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-935081f9",
#     "buyeruid": "e2b9c615-3042-4f41-8e33-b0d0087c2764",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "iAsx2ZwLT6K2iGkA6PCt1g",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "81d95072",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "59efe228"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 21 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "RRy4yRL9QGCzlHGOXQXwRQ",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-5078ed55",
#     "buyeruid": "5cfc2cb6-9023-4aea-a89d-eabc4b27738b",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "RRy4yRL9QGCzlHGOXQXwRQ",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "af4d9084",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "38ffcb68"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 22 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "vwHoBTNpR0WSDaITK0rOuw",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-e19ba728",
#     "buyeruid": "7fc11c43-5c41-4ca3-b99b-f0591f155777",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "vwHoBTNpR0WSDaITK0rOuw",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "43f46a20",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "8508ba62"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 23 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "8Dkn86BjRUmT0tr2jkC1SQ",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-e7e06abf",
#     "buyeruid": "3762db56-f405-4869-a77b-21c0454cf29a",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "8Dkn86BjRUmT0tr2jkC1SQ",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "6d89fdc1",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "c87ddddc"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 24 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "4ft9r3uPS8eHQ-A7PmqYMA",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-a10cd034",
#     "buyeruid": "ad043ad7-8e47-441e-817b-bfef70404ed1",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "4ft9r3uPS8eHQ-A7PmqYMA",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "eb2dfc73",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "6701eaf2"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 25 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "nyCl9IjNQsii9BLlWdkcgg",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-cc1a1cac",
#     "buyeruid": "8c714ca3-8c5a-44b9-bb92-f0f74f330750",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "nyCl9IjNQsii9BLlWdkcgg",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "e1d360e1",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "752ed132"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 26 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "P_Ux_Fb1ToK9AhLGhuWjdw",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-8fae01a7",
#     "buyeruid": "52f5bba5-81c8-4009-a894-1bfd09c07034",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "P_Ux_Fb1ToK9AhLGhuWjdw",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "cb7ec70d",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "5c1ba669"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 27 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "fYfMIeNMSsagsDFRIb-L_A",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-264301ff",
#     "buyeruid": "9555928f-dad4-4413-a292-03adf2b7311d",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "fYfMIeNMSsagsDFRIb-L_A",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "5b9acd80",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "492e5500"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 28 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "KX0pnFJoSnGFHEqJrHqa_A",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
# ...
#         }
#       ]
#     }
#   ],
#   "bidid": "55fdc604"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 42 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "B8vXrRALT7Krsma5llF3KA",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-8d19d67d",
#     "buyeruid": "f3db4636-d76c-4e97-81c4-577b8f95ac4b",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "B8vXrRALT7Krsma5llF3KA",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "a9a0e5c0",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "819b77bb"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 43 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "voZ9bf6sRhG3-2zdkNjGFA",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-2a5cd196",
#     "buyeruid": "741fcbdc-e01a-4fdc-95c7-3833b1fab174",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "voZ9bf6sRhG3-2zdkNjGFA",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "9429a1e2",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "8a4c371c"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 44 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "Ctd060yYT3SuRgrWVZbawA",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-ef1120aa",
#     "buyeruid": "2bc2c199-60cb-4a96-a31b-fc04315d20bb",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "Ctd060yYT3SuRgrWVZbawA",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "5001bb88",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "efe84d43"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 45 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "V3RNrUGjQuef5o08enZOqQ",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-bc61622d",
#     "buyeruid": "fd296e2b-ded9-42bc-910e-b7b7098489da",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "V3RNrUGjQuef5o08enZOqQ",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "a5275a90",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "260d19e1"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 46 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "BcfYPvZlTranG92WVzApsw",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-85c25cd7",
#     "buyeruid": "02aeeb78-7fb5-421b-81c1-cdf32abf39d7",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "BcfYPvZlTranG92WVzApsw",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "3e0108a4",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "658b5cb2"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 47 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "vL8bX5FwRd6td2CLxeg4Qw",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-3e4df7bc",
#     "buyeruid": "a862f4e7-d758-43a0-90ae-b1bfc5b1a41d",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "vL8bX5FwRd6td2CLxeg4Qw",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "435502c7",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "b4616b01"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 48 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "2wHn4OYWSQ-SU0RH-EX4sg",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-905a74df",
#     "buyeruid": "fc719f9c-91ed-4b58-a7a6-4f53e37693e0",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "2wHn4OYWSQ-SU0RH-EX4sg",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "1ec0c22c",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "ab558892"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}
#
# --- Auction 49 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "lGjAOrK9QkeGLQW2viIpEQ",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-8a2fcaa9",
#     "buyeruid": "c751f223-437a-4adf-a36c-2efe431c1f60",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "lGjAOrK9QkeGLQW2viIpEQ",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "d59c0b3f",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "0e0ecf77"
# }
#
# ✓ WON: Feedback - {"creative_status": 1, "price": 6.05, "won": true}
#
# --- Auction 50 ---
#
# BID REQUEST (OpenRTB):
# {
#   "id": "1MjDPGiUQIC7iW9QhJffeQ",
#   "imp": [
#     {
#       "id": "1",
#       "banner": {
#         "w": 300,
#         "h": 250,
#         "format": [
#           {
#             "w": 300,
#             "h": 250
#           }
#         ]
#       },
#       "tagid": "sidebar-ad-123",
#       "bidfloor": 1.5,
#       "bidfloorcur": "USD",
#       "secure": 1,
#       "ext": {
#         "billing_id": [
#           12345
#         ]
#       }
#     }
#   ],
#   "site": {
#     "id": "site-pub-123",
#     "domain": "example-publisher.com",
#     "page": "https://example-publisher.com/article",
#     "name": "Publisher",
#     "cat": null,
#     "content": null
#   },
#   "device": {
#     "ua": "Mozilla/5.0 (iPhone; CPU iPhone OS 15_0 like Mac OS X)",
#     "ip": "192.168.1.100",
#     "devicetype": 1,
#     "make": "Apple",
#     "model": "iPhone",
#     "os": "iOS"
#   },
#   "user": {
#     "id": "user-ab72944d",
#     "buyeruid": "9dedeae7-853d-411a-ac44-73b49b15d967",
#     "keywords": ""
#   },
#   "at": 2,
#   "tmax": 100,
#   "cur": [
#     "USD"
#   ],
#   "test": 1
# }
#
# → Decision: Bid $6.05 CPM with creative banner-1
#
# BID RESPONSE (OpenRTB):
# {
#   "id": "1MjDPGiUQIC7iW9QhJffeQ",
#   "seatbid": [
#     {
#       "seat": "my-buyer",
#       "bid": [
#         {
#           "id": "f7193f5d",
#           "impid": "1",
#           "price": 6.05,
#           "adid": "banner-1",
#           "adm": "<div style='background:#f0f0f0;padding:20px'>Sample Ad</div>",
#           "ext": {
#             "billing_id": 12345,
#             "impression_tracking_url": [
#               "https://track.example.com/imp?auction_id=${AUCTION_ID}&price=${AUCTION_PRICE}&creative=banner-1"
#             ]
#           }
#         }
#       ]
#     }
#   ],
#   "bidid": "1c7b4ba0"
# }
#
# ✗ Lost: Feedback - {"creative_status": 1, "price": 6.55, "won": false}

# %%
# Display metrics
print("\n" + "=" * 60)
print("PERFORMANCE METRICS")
print("=" * 60)
metrics = bidder.get_performance_metrics()
for key, value in metrics.items():
    print(f"{key.replace('_', ' ').title()}: {value}")
# Out:
# ============================================================
# PERFORMANCE METRICS
# ============================================================
# Bids Submitted: 53
# Bids Won: 27
# Win Rate: 50.943396226415096
# Total Spend: 163.35
# Average Cpm: 6.05
# Impressions Count: 27
